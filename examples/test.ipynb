# %%
import numpy as np
path = '/nfs/kun1/users/albert/realrobot_datasets/combined_2021-06-03_21_36_48_labeled.pkl'
data = np.load(open(path, 'rb'), allow_pickle=True)

# %%
data[0].keys()
# Out:
# dict_keys(['observations', 'actions', 'rewards', 'next_observations', 'terminals', 'env_infos'])

# %%
data[0]['observations']
# Out:
# [{'image': array([0.22745098, 0.23137255, 0.23137255, ..., 0.6666667 , 0.79607844,
#          0.9529412 ], dtype=float32),
#   'state': array([ 0.00365252, -0.24450369,  0.13426281,  0.06288751,  0.00308231,
#           0.01543867,  1.        ,  1.01212509]),
#   'joints': array([-1.55392253, -0.13652429,  0.4310486 , -0.00306796,  1.33916521,
#           0.        ]),
#   'ee_coord': array([ 0.00365252, -0.24450369,  0.13426281])},
#  {'image': array([0.        , 0.0627451 , 0.20784314, ..., 0.5921569 , 0.84705883,
#          0.95686275], dtype=float32),
#   'state': array([ 5.28736125e-02, -1.91934250e-01,  1.26658906e-01,  2.47385738e-02,
#           8.37885654e-03, -2.32749926e-04,  1.00000000e+00,  1.01212509e+00]),
#   'joints': array([-1.3008157 , -0.33133987,  0.64887387,  0.00306796,  1.27780604,
#           0.26844665]),
#   'ee_coord': array([ 0.05361196, -0.19198241,  0.12665326])},
#  {'image': array([0.07843138, 0.03921569, 0.03921569, ..., 0.58431375, 0.85490197,
# ...
